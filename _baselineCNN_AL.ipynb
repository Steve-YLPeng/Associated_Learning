# %% [markdown]
# ### CNN_AL

# %%
# CNN_AL dim300, act=sig+N, cri=ce
data = "tinyImageNet"
for test_count in range(5):
    for model in ["CNN_AL",]:
        layer = 4
        epoch = 200
        lr = 0.001
        aug_type = "strong"
        save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_b128/"
        out_path = f"result/{data}_{model}_l{layer}_{aug_type}_b128/"
        log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
        # !mkdir {save_path}
        # !mkdir {out_path}
        # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
        --num-layer {layer}\
        --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 300 \
        --lr-schedule plateau \
        --save-dir {save_path} \
        --out-dir {out_path} \
        --aug-type {aug_type} \
        --task image > {log}

        import gc
        gc.collect()

# %%
# CNN_AL dim300, act=sig+N, cri=ce
data = "cifar10"
for test_count in range(5):
    for model in ["CNN_AL",]:
        layer = 4
        epoch = 200
        lr = 0.001
        aug_type = "strong"
        save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_b128/"
        out_path = f"result/{data}_{model}_l{layer}_{aug_type}_b128/"
        log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
        # !mkdir {save_path}
        # !mkdir {out_path}
        # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
        --num-layer {layer}\
        --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 300 \
        --lr-schedule plateau \
        --save-dir {save_path} \
        --out-dir {out_path} \
        --aug-type {aug_type} \
        --task image > {log}

        import gc
        gc.collect()

# %%
# CNN_AL dim300, act=sig+N, cri=ce
data = "cifar100"
for test_count in range(5):
    for model in ["CNN_AL",]:
        layer = 4
        epoch = 200
        lr = 0.001
        aug_type = "strong"
        save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_b128/"
        out_path = f"result/{data}_{model}_l{layer}_{aug_type}_b128/"
        log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
        # !mkdir {save_path}
        # !mkdir {out_path}
        # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
        --num-layer {layer}\
        --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 300 \
        --lr-schedule plateau \
        --save-dir {save_path} \
        --out-dir {out_path} \
        --aug-type {aug_type} \
        --task image > {log}

        import gc
        gc.collect()

# %% [markdown]
# ### VGG_AL

# %%
# VGG_AL dim500, act=sig+sig, cri=ce
data = "cifar10"
for test_count in range(1):
    for model in ["VGG_AL",]:
        for aug_type in ["strong",]:
            layer = 4
            epoch = 200
            lr = 0.0001
            
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %%
# VGG_AL dim500, act=sig+sig, cri=ce
data = "cifar100"
for test_count in range(1):
    for model in ["VGG_AL",]:
        layer = 4
        epoch = 200
        lr = 0.0001
        aug_type = "strong"
        save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
        out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
        log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
        # !mkdir {save_path}
        # !mkdir {out_path}
        # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
        --num-layer {layer}\
        --batch-train 128 --batch-test 1024\
        --lr {lr} --l1-dim 300 --label-emb 500 \
        --lr-schedule plateau \
        --save-dir {save_path} \
        --out-dir {out_path} \
        --aug-type {aug_type} \
        --task image > {log}

        import gc
        gc.collect()

# %%
# VGG_AL dim500, act=sig+sig, cri=ce
data = "tinyImageNet"
for test_count in range(1):
    for model in ["VGG_AL",]:
        layer = 4
        epoch = 200
        lr = 0.0001
        aug_type = "strong"
        save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
        out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
        log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
        # !mkdir {save_path}
        # !mkdir {out_path}
        # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
        --num-layer {layer}\
        --batch-train 128 --batch-test 1024\
        --lr {lr} --l1-dim 300 --label-emb 500 \
        --lr-schedule plateau \
        --save-dir {save_path} \
        --out-dir {out_path} \
        --aug-type {aug_type} \
        --task image > {log}

        import gc
        gc.collect()

# %% [markdown]
# ### all in 1

# %%
### 0429: (all in one)confidence max / adapt time optimized / test batch 1024
for data in ["cifar10","cifar100", "tinyImageNet"]:
    for test_count in range(6,7):
        for model in ["VGG_AL","resnet_AL",]:
            for aug_type in ["strong",]:
                layer = 4
                epoch = 200
                lr = 0.0001
                
                save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_1024/"
                out_path = f"result/{data}_{model}_l{layer}_{aug_type}_1024/"
                log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
                # !mkdir {save_path}
                # !mkdir {out_path}
                # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
                --num-layer {layer}\
                --batch-train 128 --batch-test 1024\
                --lr {lr} --l1-dim 128 --label-emb 1024 \
                --lr-schedule plateau \
                --save-dir {save_path} \
                --out-dir {out_path} \
                --aug-type {aug_type} \
                --task image > {log}

                import gc
                gc.collect()

# %%
### 0429: (all in one)confidence max / adapt time optimized / test batch 1024
for data in ["cifar10", "cifar100", "tinyImageNet"]:
    for test_count in range(6,7):
        for model in ["CNN_AL",]:
            for aug_type in ["strong",]:
                layer = 4
                epoch = 200
                lr = 0.001
                
                save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_1024/"
                out_path = f"result/{data}_{model}_l{layer}_{aug_type}_1024/"
                log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
                # !mkdir {save_path}
                # !mkdir {out_path}
                # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
                --num-layer {layer}\
                --batch-train 128 --batch-test 1024\
                --lr {lr} --l1-dim 128 --label-emb 1024 \
                --lr-schedule plateau \
                --save-dir {save_path} \
                --out-dir {out_path} \
                --aug-type {aug_type} \
                --task image > {log}

                import gc
                gc.collect()

# %% [markdown]
# ### ResNet 18

# %%
for data in ["cifar10"]:
    for test_count in range(2,3):
        for model in ["resnet_AL",]:
            for aug_type in ["strong",]:
                layer = 4
                epoch = 200
                lr = 0.0001
                
                save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
                out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
                log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
                # !mkdir {save_path}
                # !mkdir {out_path}
                # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
                --num-layer {layer}\
                --batch-train 128 --batch-test 1024\
                --lr {lr} --l1-dim 300 --label-emb 500 \
                --lr-schedule plateau \
                --save-dir {save_path} \
                --out-dir {out_path} \
                --aug-type {aug_type} \
                --task image > {log}

                import gc
                gc.collect()

# %%
# resnet_AL dim500, act=sig+sig, cri=ce
data = "cifar100"
for test_count in range(1):
    for model in ["resnet_AL",]:
        for aug_type in ["strong",]:
            layer = 4
            epoch = 200
            lr = 0.0001
            
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %%
# resnet_AL dim500, act=sig+sig, cri=ce
data = "tinyImageNet"
for test_count in range(1):
    for model in ["resnet_AL",]:
        for aug_type in ["strong",]:
            layer = 4
            epoch = 200
            lr = 0.0001
            
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %% [markdown]
# ### layer by layer training

# %%
for data in ["cifar100"]:
    for test_count in range(1):
        for model in ["resnet_AL",]:
            layer = 4
            epoch = 300
            lr = 0.0001
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_lbl.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()
# Out:
# mkdir: cannot create directory ‘ckpt/cifar100_resnet_AL_l4_strong_lbl_pre/’: File exists
# mkdir: cannot create directory ‘result/cifar100_resnet_AL_l4_strong_lbl_pre/’: File exists
# ...
#  42%|█████████████████                        | 163/391 [00:10<00:14, 16.24it/s]

# %%
for data in ["cifar10","tinyImageNet",]:
    for test_count in range(1,2):
        for model in ["VGG_AL","resnet_AL",]:
            layer = 4
            epoch = 600
            lr = 0.0001
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_lbl.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %%
for data in ["cifar10","cifar100","tinyImageNet"]:
    for test_count in range(1):
        for model in ["CNN_AL",]:
            layer = 4
            epoch = 500
            lr = 0.001
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_lbl_pre_125/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}_lbl_pre_125/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_lbl.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %% [markdown]
# ### BP

# %%
for data in ["cifar10","cifar100","tinyImageNet"]:
    for test_count in range(1):
        for model in ["CNN",]:
            epoch = 300
            lr = 0.0001
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_{aug_type}/"
            out_path = f"result/{data}_{model}_{aug_type}/"
            log = f"{out_path}/{data}_{model}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_bp.py --dataset {data} --model {model} --epoch {epoch} \
            --batch-train 128 --batch-test 1024\
            --lr {lr} \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %%
for data in ["cifar10","cifar100","tinyImageNet"]:
    for test_count in range(1):
        for model in ["VGG","resnet",]:
            epoch = 300
            lr = 0.0001
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_{aug_type}/"
            out_path = f"result/{data}_{model}_{aug_type}/"
            log = f"{out_path}/{data}_{model}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_bp.py --dataset {data} --model {model} --epoch {epoch} \
            --batch-train 128 --batch-test 1024\
            --lr {lr} \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()

# %% [markdown]
# #### side

# %%
for data in ["cifar10","cifar100","tinyImageNet",]:
    for test_count in range(1):
        for model in ["resnet_AL_side",]:
            layer = 4
            epoch = 480
            lr = 0.0005
            aug_type = "strong"
            save_path = f"ckpt/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            out_path = f"result/{data}_{model}_l{layer}_{aug_type}_lbl_pre/"
            log = f"{out_path}/{data}_{model}_l{layer}_{test_count}.log"
            # !mkdir {save_path}
            # !mkdir {out_path}
            # !python3 dis_train_cnn_lbl.py --dataset {data} --model {model} --epoch {epoch} \
            --num-layer {layer}\
            --batch-train 128 --batch-test 1024\
            --lr {lr} --l1-dim 300 --label-emb 500 \
            --lr-schedule plateau \
            --save-dir {save_path} \
            --out-dir {out_path} \
            --aug-type {aug_type} \
            --task image > {log}

            import gc
            gc.collect()
