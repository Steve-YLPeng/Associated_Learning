# %%
data = "dbpedia_14"
model = "transformeral"
layer = 10
log = f"result/{data}/{data}_{model}_l{layer}.log"
# !mkdir result/{data}/
# !mkdir ckpt/{data}/
# !python3 dis_train_side.py --dataset {data} --model {model} --epoch 50 --batch-size 128\
--max-len 500 --l1-dim 300 --label-emb 128 \
--num-layer {layer} --lr 0.0001 --task text > {log}
# Out:
# mkdir: cannot create directory ‘result/dbpedia_14/’: File exists
# mkdir: cannot create directory ‘ckpt/dbpedia_14/’: File exists
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:02<00:00, 149993.24it/s]
# Train 0 | Acc 0.0 (0/1): 100%|████████████████████| 1/1 [00:00<00:00,  2.57it/s]
# /opt/conda/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# ...

# %%
from utils import *
dataset = "dbpedia_14"
from datasets import load_dataset
train_data = load_dataset(dataset, split='train[78901:78903]')
test_data = load_dataset(dataset, split='test')
tf = 'content'
train_text = [b[tf] for b in train_data]
test_text = [b[tf] for b in test_data]
train_label = [b['label'] for b in train_data]
test_label = [b['label'] for b in test_data]
clean_train = [data_preprocessing(t, True) for t in train_text]
clean_test = [data_preprocessing(t, True) for t in test_text]

vocab = create_vocab(clean_train)
# Out:
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# total count words 42
# vocab size 43

# %%
clean_train
# Out:
# ['<unk>',
#  'kraemer middle school established part placentiayorba linda unified school district 1960 located placentia california school made 850 students served 69 staff members feeder school valencia high school 57 students hispanic 58 students eligible freelunch programdistinguished alumni includecitation needed nfl player chris draft olympic softball star michelle granger']

# %%
# 1115
# max len 
#   imdb/dbpidia 500
#   agnews 128
# emb dim 300
# L1 dim 300 
# batch 128

data = "dbpedia_14"
for model in ["linearal","lstmal","transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}_prefix.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()
# Out:
# mkdir: cannot create directory ‘result/dbpedia_14/’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//dbpedia_14/’: File exists
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 106552.04it/s]
# Train 0 | Acc 0.07142678571428572 (39999/560000): 100%|█| 4375/4375 [02:15<00:00
# Train 1 | Acc 0.07142857142857142 (40000/560000): 100%|█| 4375/4375 [02:09<00:00
# Train 2 | Acc 0.07142857142857142 (40000/560000): 100%|█| 4375/4375 [02:08<00:00
# Train 3 | Acc 0.07142678571428572 (39999/560000): 100%|█| 4375/4375 [02:16<00:00
# ...

# %%
# 1115
# max len 
#   imdb/dbpidia 500
#   agnews 128
# emb dim 300
# L1 dim 300 
# batch 128

data = "dbpedia_14"
#for model in ["linearal","lstmal","transformeral"]:
for model in ["transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
    #for mask in [4,5]:
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()
# Out:
# mkdir: cannot create directory ‘result/dbpedia_14/’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//dbpedia_14/’: File exists
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/home/user/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 105779.20it/s]
# Train 0 | Acc 0.04768571428571428 (26704/560000): 100%|█| 4375/4375 [05:27<00:00
# Train 1 | Acc 0.04202142857142857 (23532/560000): 100%|█| 4375/4375 [05:22<00:00
# Train 2 | Acc 0.03882142857142857 (21740/560000): 100%|█| 4375/4375 [05:22<00:00
# Train 3 | Acc 0.0365125 (20447/560000): 100%|█| 4375/4375 [05:22<00:00, 13.58it/
# ...

# %%
# 1115
# max len 
#   imdb/dbpidia 500
#   agnews 128
# emb dim 300
# L1 dim 300 
# batch 128

for data in ["ag_news"]:
    #for model in ["transformeral"]:
    for model in ["linearal","lstmal","transformeral"]:
        #for layer in range(1,11):
        for layer in [5]:
            log = f"result/{data}/{data}_{model}_l{layer}.log"
            # !mkdir result/{data}/
            # !mkdir ckpt/{data}/
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch 50 \
            --batch-size 128 \
            --max-len 177 --l1-dim 300 --label-emb 128 \
            --num-layer {layer} --lr 0.0001 --task text > {log}
        import gc
        gc.collect()  

for data in ["imdb","dbpedia_14"]:
    #for model in ["transformeral"]:
    for model in ["linearal","lstmal","transformeral"]:
        #for layer in range(1,11):
        for layer in [5]:
            log = f"result/{data}/{data}_{model}_l{layer}.log"
            # !mkdir result/{data}/
            # !mkdir ckpt/{data}/
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch 50 \
            --batch-size 128 \
            --max-len 500 --l1-dim 300 --label-emb 128 \
            --num-layer {layer} --lr 0.0001 --task text > {log}
        import gc
        gc.collect()
# Out:
# mkdir: cannot create directory ‘result/ag_news/’: File exists
# mkdir: cannot create directory ‘ckpt/ag_news/’: File exists
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 111157.16it/s]
# Train 0 | Acc 0.6771083333333333 (81253/120000): 100%|█| 938/938 [00:06<00:00, 1
# Train 1 | Acc 0.9253666666666667 (111044/120000): 100%|█| 938/938 [00:06<00:00,
# Train 2 | Acc 0.9347 (112164/120000): 100%|██| 938/938 [00:06<00:00, 153.26it/s]
# Train 3 | Acc 0.9399166666666666 (112790/120000): 100%|█| 938/938 [00:06<00:00,
# ...

# %%
# 1115
# max len 
#   imdb/dbpidia 500
#   agnews 128
# emb dim 300
# L1 dim 300 
# batch 128

data = "ag_news"
for model in ["linearal","lstmal","transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}_prefix.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 177 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 177 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()

data = "imdb"
for model in ["linearal","lstmal","transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}_prefix.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --prefix-mask True \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()
# Out:
# mkdir: cannot create directory ‘result/ag_news/’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//ag_news/’: File exists
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 108373.13it/s]
# Train 0 | Acc 0.25393333333333334 (30472/120000): 100%|█| 938/938 [00:23<00:00,
# Train 1 | Acc 0.24941666666666668 (29930/120000): 100%|█| 938/938 [00:33<00:00,
# Train 2 | Acc 0.24844166666666667 (29813/120000): 100%|█| 938/938 [00:23<00:00,
# Train 3 | Acc 0.24810833333333332 (29773/120000): 100%|█| 938/938 [00:33<00:00,
# ...

# %%
data = "ag_news"
for model in ["linearal","lstmal","transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}_prefix.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 177 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 177 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()

data = "imdb"
for model in ["linearal","lstmal","transformeral"]:
    layer = 10
    epoch = 10
    lr = 0.0001
    #for layer in range(1,11):
    for mask in range(1,layer+1):
        save = f"mask{mask}/"
        load = f"mask{mask-1}/"
        log = f"result/{data}/{data}_{model}_l{layer}_m{mask}_prefix.log"
        # !mkdir result/{data}/
        # !mkdir ckpt/{save}/
        # !mkdir ckpt/{save}/{data}/
        if mask != 1:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --load-dir ./ckpt/{load} \
            --task text > {log}
        else:
            # !python3 dis_train_side.py --dataset {data} --model {model} --epoch {epoch} \
            --max-len 500 \
            --num-layer {layer} --batch-size 128 --lr {lr} --l1-dim 300 --label-emb 128 \
            --lr-schedule plateau \
            --train-mask {mask} \
            --save-dir ./ckpt/{save} \
            --task text > {log}
        import gc
        gc.collect()
# Out:
# mkdir: cannot create directory ‘result/ag_news/’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//’: File exists
# mkdir: cannot create directory ‘ckpt/mask1//ag_news/’: File exists
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# Using custom data configuration default
# Reusing dataset ag_news (/home/user/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 110823.01it/s]
# Train 0 | Acc 0.19359166666666666 (23231/120000): 100%|█| 938/938 [00:04<00:00,
# Train 1 | Acc 0.18753333333333333 (22504/120000): 100%|█| 938/938 [00:04<00:00,
# Train 2 | Acc 0.18515 (22218/120000): 100%|██| 938/938 [00:04<00:00, 205.44it/s]
# Train 3 | Acc 0.18175833333333333 (21811/120000): 100%|█| 938/938 [00:04<00:00,
# ...
