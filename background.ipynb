# %%
# LinearAL 

#data = "ag_news"
#data = "imdb"
data = "dbpedia_14"
model =  "linearal"
#for layer in [2,3,4,5,10]:
for layer in [10]:
    log = f"result/{data}_{model}_l{layer}.log"
    # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} > {log}
# Out:
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 110143.44it/s]
# Train 0 | Acc 0.9546964285714286 (534630/560000): 100%|█| 8750/8750 [01:08<00:00
# ...
# 100%|██████████████████████████████████████| 1094/1094 [00:01<00:00, 998.37it/s]
# Train 1 | Acc 0.9811071428571428 (549420/560000): 100%|█| 8750/8750 [02:54<00:00
# ...
# 100%|██████████████████████████████████████| 1094/1094 [00:03<00:00, 316.05it/s]
# Train 2 | Acc 0.9814517857142857 (549613/560000): 100%|█| 8750/8750 [01:15<00:00
# ...
# 100%|██████████████████████████████████████| 1094/1094 [00:03<00:00, 304.57it/s]
# Train 3 | Acc 0.9780196428571428 (547691/560000): 100%|█| 8750/8750 [01:57<00:00
# ...

# %%
# LSTMAL

#data = "ag_news"
#data = "imdb"
data = "dbpedia_14"
model =  "lstmal"
for layer in [2,3,4,5,10]:
    log = f"result/{data}_{model}_l{layer}.log"
    # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} > {log}
# Out:
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 109712.66it/s]
# Train 0 | Acc 0.9700839285714286 (543247/560000): 100%|█| 8750/8750 [00:37<00:00
# ...
# 100%|█████████████████████████████████████| 1094/1094 [00:01<00:00, 1000.03it/s]
# Train 1 | Acc 0.9888571428571429 (553760/560000): 100%|█| 8750/8750 [00:37<00:00
# ...
# 100%|█████████████████████████████████████| 1094/1094 [00:01<00:00, 1001.52it/s]
# Train 2 | Acc 0.9910535714285714 (554990/560000): 100%|█| 8750/8750 [00:37<00:00
# ...
# 100%|█████████████████████████████████████| 1094/1094 [00:01<00:00, 1000.90it/s]
# Train 3 | Acc 0.9925910714285714 (555851/560000): 100%|█| 8750/8750 [00:37<00:00
# ...

# %%
# TransformerAL

model =  "transformeral"
for data in ["ag_news","imdb","transformeral"]:

    for layer in [2,3,4,5,10]:
    #for layer in [3]:   
        log = f"result/{data}_{model}_l{layer}.log"
        # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} > {log}
