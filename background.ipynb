# %%
for layer in [2,3,4,5,10]:
    data = "ag_news"
    for model in ["linearal","lstmal","transformeral"]:
        log = f"result/{data}_{model}_l{layer}.log"
        # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} --max-len 1000 --l1-dim 300 > {log}
    data = "imdb"
    for model in ["linearal","lstmal","transformeral"]:
        log = f"result/{data}_{model}_l{layer}.log"
        # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} --max-len 500 --l1-dim 300 > {log}
    data = "dbpedia_14"
    for model in ["linearal","lstmal"]:
        log = f"result/{data}_{model}_l{layer}.log"
        # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} --max-len 500 --l1-dim 300 > {log}
# Out:
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 111788.77it/s]
# Train 0 | Acc 0.8714166666666666 (104570/120000): 100%|█| 1875/1875 [00:07<00:00
# Train 1 | Acc 0.930325 (111639/120000): 100%|█| 1875/1875 [00:07<00:00, 264.99it
# Train 2 | Acc 0.9382333333333334 (112588/120000): 100%|█| 1875/1875 [00:07<00:00
# Train 3 | Acc 0.9428333333333333 (113140/120000): 100%|█| 1875/1875 [00:06<00:00
# Train 4 | Acc 0.9462166666666667 (113546/120000): 100%|█| 1875/1875 [00:06<00:00
# Train 5 | Acc 0.9487 (113844/120000): 100%|█| 1875/1875 [00:06<00:00, 270.71it/s
# ...

# %%
for layer in [10]:
    data = "dbpedia_14"
    for model in ["lstmal"]:
        log = f"result/{data}_{model}_l{layer}.log"
        # !python3 dis_train_al.py --dataset {data} --model {model} --epoch 20 --num-layer {layer} --max-len 500 --l1-dim 300 > {log}
# Out:
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 108572.97it/s]
# Train 0 | Acc 0.9665767857142857 (541283/560000): 100%|█| 8750/8750 [07:52<00:00
# Train 1 | Acc 0.9895446428571428 (554145/560000): 100%|█| 8750/8750 [07:55<00:00
# Train 2 | Acc 0.9918125 (555415/560000): 100%|█| 8750/8750 [07:56<00:00, 18.37it
# Train 3 | Acc 0.9926803571428572 (555901/560000): 100%|█| 8750/8750 [07:56<00:00
# Train 4 | Acc 0.9943071428571428 (556812/560000): 100%|█| 8750/8750 [07:56<00:00
# Train 5 | Acc 0.9945678571428571 (556958/560000): 100%|█| 8750/8750 [07:57<00:00
# Train 6 | Acc 0.9942625 (556787/560000): 100%|█| 8750/8750 [10:46<00:00, 13.54it
# ...

# %%
# TransformerAL
#data = "ag_news"
data = "dbpedia_14"
model =  ""
# !python3 dis_train_tr.py --dataset {data} --epoch 5  --max-len 500 --l1-dim 300 --lr 0.0005
# Out:
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# Reusing dataset dbpedia_14 (/root/.cache/huggingface/datasets/dbpedia_14/dbpedia_14/2.0.0/01dab9e10d969eadcdbc918be5a09c9190a24caeae33b10eee8f367a1e3f1f0c)
# total count words 887880
# vocab size 30000
# loading glove vocabs...: 100%|██████| 400000/400000 [00:03<00:00, 105804.17it/s]
# found 28354 words in glove
# Start Training
# 0 | Acc 82.37285714285714| L1 0.0002 + nan | L2 0.0001 + nan: 100%|█| 8750/8750
# Acc 7.142857142857143 (5000/70000): 100%|██| 1094/1094 [00:02<00:00, 409.18it/s]
# Test Epoch 0 Acc 7.142857142857143
# 1 | Acc 7.142857142857143| L1 0.0 + nan | L2 0.0 + nan: 100%|█| 8750/8750 [01:32
# Acc 7.142857142857143 (5000/70000): 100%|██| 1094/1094 [00:02<00:00, 408.21it/s]
# Test Epoch 1 Acc 7.142857142857143
# 2 | Acc 7.142857142857143| L1 0.0 + nan | L2 0.0 + nan: 100%|█| 8750/8750 [01:32
# ...
